# %%
# Using enumerate()

students = ['Alice', 'Bob', 'Carol', 'David']

# %%
# With enumerate
for index, name in enumerate(students):
    print(f'Student #{index + 1}: {name}')
# Out:
# Student #1: Alice
# Student #2: Bob
# Student #3: Carol
# Student #4: David
