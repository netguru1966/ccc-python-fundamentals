# %%
# List in numbers
numbers = [1, 2, 3, 4, 5]

# %%
# Old Way
doubled = []
for num in numbers:
    doubled.append(num * 2)
print(doubled)
# Out:
# [2, 4, 6, 8, 10]

# %%
# New Way
doubled = [ num * 2 for num in numbers]
print(doubled)
# Out:
# [2, 4, 6, 8, 10]
