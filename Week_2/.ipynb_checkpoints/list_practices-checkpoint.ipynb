# %%
empty_list = []

# %%
# List of numbers
ages = [25, 32, 28, 45, 19]

# %%
# List of strings
names = ['Alice', 'Bob', 'Carol', 'David']

# %%
# List of mixed types
person = ['Alice',25,'Engineer', True]
