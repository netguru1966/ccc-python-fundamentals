# %%
# Start with an empty list
scores = []

# %%
# Add items one by one
scores.append(95)
print(scores)
# Out:
# [95]

# %%
# Add items one by one
scores.append(87)
print(scores)
# Out:
# [95, 87]

# %%
# Add items one by one
scores.append(92)
print(scores)
# Out:
# [95, 87, 92]

# %%
# This is how you BUILD lists
# Very common in data processing
# You'll with use append() constantly
