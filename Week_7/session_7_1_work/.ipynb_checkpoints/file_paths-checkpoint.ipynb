# %% [markdown]
# ## Working with File Paths

# %%
import os

# Check current directory
print(os.getcwd())
# /home/claude
# Out:
# /Users/v.henry/Desktop/python/python_2026/Week_7/session_7_1_work

# %%
# List files in directory
print(os.listdir('.'))
# ['file1.txt', 'file2.txt', ...]
# Out:
# ['reading_file_with.ipynb', 'file_paths.ipynb', 'reading_file.ipynb', '.ipynb_checkpoints', 'read_methods.ipynb']

# %%
# Check if file exists
if os.path.exists('sample.txt'):
    print('File found!')
else:
    print('File not found!')
# Out:
# File not found!

# %%
# Join paths (works on any OS!)

filepath = os.path.join('data', 'input', 'file.txt')

# data/input/file.txt (Linux)
# data\input\file.txt (Windows)
# Portable across operating systems!
