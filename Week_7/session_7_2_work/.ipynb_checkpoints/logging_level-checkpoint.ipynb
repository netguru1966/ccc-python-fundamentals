# %% [markdown]
# ## Basic Logging Example

# %%
import logging

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

# %%
# Use logging instead of print

def process_file(filename):
    logging.info(f'Processing {filename}')
    try:
        with open(filename, 'r') as f:
            data = f.read()
            logging.info(f'Loaded {len(data)} characters')
            return data
    except Exception as e:
        logging.error(f'Failed to process {filename}: {e}')
        return None

# %%
# Professional logging!

# %%
process_file('../data/output.txt')
# Out:
# 2026-02-26 20:48:03,136 - INFO - Processing ../data/output.txt
# 2026-02-26 20:48:03,139 - INFO - Loaded 60 characters
# 'Hello, World!\nThis is line 2\n\nThis is line 3\nThis is line 4\n'
