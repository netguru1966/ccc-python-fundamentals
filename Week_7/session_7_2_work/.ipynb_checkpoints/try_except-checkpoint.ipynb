# %% [markdown]
# ## Your First Try/Except

# %%
# Handle invalid input

try:
    age = int(input('Enter your age: '))
    if value < 0:
        # Raise a ValueError if the condition is not met
        raise ValueError("Input value must be a positive number")
    # Rest of the function logic
    print(f'You are {age} years old')
    
except ValueError:
    print('Error: Please enter a valid number')
print('Program continues!')
# Out:
# Enter your age:  -1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       3 try:
#       4     age = int(input('Enter your age: '))
# ----> 5     if value < 0:
#       6         # Raise a ValueError if the condition is not met
#       7         raise ValueError("Input value must be a positive number")
#       8     # Rest of the function logic
#
# NameError: name 'value' is not defined

# %%
# If user enters 'abc':
# Error: Please enter a valid number
# Program continues!

# %%
# If user enters '25':
# You are 25 years old
# Program continues!
# No crash either way!
