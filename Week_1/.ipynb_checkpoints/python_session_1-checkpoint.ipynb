# %%
print("Hello, World")
# Out:
# Hello, World

# %%
print("Hello, World")
# Out:
# Hello, World

# %%
print("Hello, World"
# Out:
#   Cell In[3], line 1
#     print("Hello, World"
#                         ^
# SyntaxError: incomplete input

# %%
print("I'm learning Python")
# Out:
# I'm learning Python

# %%
print("This is exciting")
# Out:
# This is exciting

# %%
#About you (Change to your info)
name = 'Vanay Henry'
age = 55    
previous_career = 'Police Officer'   
wants_ml = True

print(name)
print(age)
print(previous_career)
# Out:
# Vanay Henry
# 55
# Police Officer

# %%
#Basic Math
total = 10 + 5
print(total)
# Out:
# 15

# %%
#Monthly Expenses
rent = 1500
food = 400
transport = 200
total_expenses = rent + food  + transport
print(total_expenses)
# Out:
# 2100
