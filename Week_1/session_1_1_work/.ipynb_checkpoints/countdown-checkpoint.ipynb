# %%
#Calculate days until ML start
weeks_left = 8
days_of_week = 7

# %%
total_days = weeks_left * days_of_week

# %%
total_hours = total_days * 24

# %%
print('Only ' + str(total_days) + ' days until ML program.')
# Out:
# Only 56 days until ML program.

# %%
print('Wow only ' + str(total_hours) + ' hours until ML program.')
# Out:
# Wow only 1344 hours until ML program.
