# %% [markdown]
# ### Exercise 3: Calculator Functions

# %%
# Build calculator with functions:

# %%
numbers =

# %%
def calculate_average(numbers): 
    return sum(numbers) / len(numbers)

def find_maximum(numbers): 
    return max(numbers)

def count_above_threshols(numbers,threshold): 
    count = 0
    for num in numbers:
        if num > threshold:
            count +=1
    return count

# %%
# Test each function:

print(f'Average: {calculate_average([85, 92, 78, 95, 88, 76]):.2f}')
print(f'Maximum: {find_maximum([85, 92, 78, 95, 88, 76])}')
# Out:
# Average: 85.67
# Maximum: 95

# %%
# Real Data Analysis Functions
