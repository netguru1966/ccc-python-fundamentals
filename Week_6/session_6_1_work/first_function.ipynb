# %% [markdown]
# ## Define the function

# %%
def greet():
    print('Hello, Vanay!')
    print('Welcome to functions!')

# %%
# Call the function (use it)

greet()

# Output:
# Hello, World!
# Welcome to functions!
# Out:
# Hello, Vanay!
# Welcome to functions!

# %%
# Call it again!

greet()
# Out:
# Hello, Vanay!
# Welcome to functions!

# %%
# Same output again!
# Define once, use many times!
