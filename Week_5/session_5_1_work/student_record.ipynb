# %% [markdown]
# ### Student Records

# %%
# Method 2: Empty then add

student = {}
student['name'] = 'Vanay Henry'
student['student_id'] = '3058734'
student['age'] = 59
student['graduation_year'] = '2028'
student['major'] = 'MLU'
student['gpa'] = 3.5
student['courses'] = 'Python 101', 'Prompt Engineering', 'Agentic AI'

# %%
print(student)
# Out:
# {'name': 'Vanay Henry', 'student_id': '3058734', 'age': 59, 'graduation_year': '2028', 'major': 'MLU', 'gpa': 3.5, 'courses': ('Python 101', 'Prompt Engineering', 'Agentic AI')}

# %%
# Get all values

values = student.values()
print(values)
# Out:
# dict_values(['Vanay Henry', '3058734', 59, 'MLU', 3.5, ('Python 101', 'Prompt Engineering')])

# %%
# Update GPA for Student

gpa = student.update({'gpa': 3.8})
print(gpa)
# Out:
# None

# %%
values = student.values()
print(values)
# Out:
# dict_values(['Vanay Henry', '3058734', 59, 'MLU', 3.8, ('Python 101', 'Prompt Engineering')])

# %%
print(student)
# Out:
# {'name': 'Vanay Henry', 'student_id': '3058734', 'age': 59, 'graduation_year': '2028', 'major': 'MLU', 'gpa': 3.5, 'courses': ('Python 101', 'Prompt Engineering')}
