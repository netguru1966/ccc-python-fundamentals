# %% [markdown]
# ### Student grades:

# %%
gradebook = {
    'Alice': {'math': 95, 'eng': 92, 'sci': 88},
    'Bob': {'math': 87, 'eng': 90, 'sci': 85},
    'Carol': {'math': 92, 'eng': 88, 'sci': 94}
}

# %%
# Analyze:
# 1. Average per student
# 2. Average per subject (across all students)
# 3. Top student overall
# 4. Best subject for each student
