# %%
#About Me

name = 'Vanay Henry'
age = 55    
previous_career = 'Police Officer'   
wants_ml = True

# %%
print(name)
# Out:
# Vanay Henry

# %%
print(age)  # Added the missing closing parenthesis
# Out:
# 55

# %%
print(previous_career)
# Out:
# Police Officer
