# %%
# Build College business logic:

gpa = 3.7
test_score = 1280
extracurriculars = True
essay_qualify = 'excellent'

# %%
if gpa >= 3.8 and test_score >= 1400:
    print('Admissions -  Accepted')

# %%
if gpa >= 3.5 and test_score >= 1200 or extracurriculars:
    print('Admissions and Extracurriculars -  Accepted')
# Out:
# Admissions and Extracurriculars -  Accepted

# %%
if essay_qualify == 'excellent' and gpa >= 3.0:
    print('Essay -  Accepted')
# Out:
# Essay -  Accepted
