# %%
# Check if you have a passing grade

# %%
grade = 85

# %%
if grade >= 60:
    print('You Passed - Congratulations!!!')
print('Check grade completed.')
# Out:
# You Passed - Congratulations!!!
# Check grade completed.

# %%
# If grade is 50
# The indented code is ignored
